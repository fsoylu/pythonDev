# %% [markdown]
# ## Sets

# %%
set()
{}
# Out:
# {}

# %%
set("hello")
# Out:
# {'e', 'h', 'l', 'o'}

# %%
set()
# Out:
# set()

# %%
print(set("techpro education"))
# Out:
# {'r', 'h', 'u', 'i', 'd', ' ', 'p', 'e', 'a', 'c', 't', 'n', 'o'}

# %%
set("techpro education")
# Out:
# {' ', 'a', 'c', 'd', 'e', 'h', 'i', 'n', 'o', 'p', 'r', 't', 'u'}

# %%
type({'e', 'h', 'l', 'o'})
# Out:
# set

# %%
{"blue","green","white","blue","red"}
# Out:
# {'blue', 'green', 'red', 'white'}

# %%
{"key" : "value"} # dictionary
# Out:
# {'key': 'value'}

# %%
set([1,2,1,3,5,5,6,1,2,4,5,8])
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
empty_set = {} # boş dict oluşturmuş olduk 
empty_set
# Out:
# {}

# %%
type(empty_set)
# Out:
# dict

# %%
empty_set_1 = set()
empty_set_1
# Out:
# set()

# %%
type(empty_set_1)
# Out:
# set

# %%
liste_1 = ["kalem", "kağıt", "silgi", "kalem"]
liste_1
# Out:
# ['kalem', 'kağıt', 'silgi', 'kalem']

# %%
set_1 = set(liste_1)

# %%
set_1
# Out:
# {'kalem', 'kağıt', 'silgi'}

# %%
len(set_1)
# Out:
# 3

# %%
set_1.add(1)

# %%
set_1
# Out:
# {1, 'kalem', 'kağıt', 'silgi'}

# %%
set("mehmet")
# Out:
# {'e', 'h', 'm', 't'}

# %%
print(set("mehmet"))
# Out:
# {'e', 'm', 'h', 't'}

# %%
alfabe = "a b c d e f g h ".split()
alfabe
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']

# %%
print(set(alfabe))
# Out:
# {'g', 'h', 'd', 'f', 'e', 'a', 'c', 'b'}

# %%
print(set([1,5,4,3,6,8,7]))
# Out:
# {1, 3, 4, 5, 6, 7, 8}

# %%
set_2 = {1,5,2.0,4,1.0,2}
set_2
# Out:
# {1, 2.0, 4, 5}

# %%
set_3 = {True, False, 1,4,0,2}
set_3
# Out:
# {False, True, 2, 4}

# %%
set_4 = {0,1,True, False, 1,4,0,2}
set_4
# Out:
# {0, 1, 2, 4}

# %%
1 == 1.0
# Out:
# True

# %% [markdown]
# # Union , Intersection, Difference

# %%
a = set("malatya")
a
# Out:
# {'a', 'l', 'm', 't', 'y'}

# %%
b = set("kayısı")
b
# Out:
# {'a', 'k', 's', 'y', 'ı'}

# %%
a - b
# Out:
# {'l', 'm', 't'}

# %%
a.difference(b)
# Out:
# {'l', 'm', 't'}

# %%
b-a
# Out:
# {'k', 's', 'ı'}

# %%
b.difference(a)
# Out:
# {'k', 's', 'ı'}

# %%
a & b
# Out:
# {'a', 'y'}

# %%
b & a
# Out:
# {'a', 'y'}

# %%
a.intersection(b)
# Out:
# {'a', 'y'}

# %%
a + b  # setlerde toplama işlemi yoktur onun yerine union kullanılır
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 a + b  # setlerde toplama işlemi yoktur onun yerine union kullanılır
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a | b
# Out:
# {'a', 'k', 'l', 'm', 's', 't', 'y', 'ı'}

# %%
a.union(b)
# Out:
# {'a', 'k', 'l', 'm', 's', 't', 'y', 'ı'}

# %%
set_5 = set("fıstık")
set_5
# Out:
# {'f', 'k', 's', 't', 'ı'}

# %%
set_6 = set("fındık")
set_6
# Out:
# {'d', 'f', 'k', 'n', 'ı'}

# %%
set_5 - set_6
# Out:
# {'s', 't'}

# %%
set_6 - set_5
# Out:
# {'d', 'n'}

# %%
set_5 | set_6
# Out:
# {'d', 'f', 'k', 'n', 's', 't', 'ı'}

# %%
set_5 - set_6 | set_6 - set_5
# Out:
# {'d', 'n', 's', 't'}

# %%
set_5.symmetric_difference(set_6)
# Out:
# {'d', 'n', 's', 't'}

# %%
set_5.difference(set_6)
# Out:
# {'s', 't'}

# %%
set_5.difference_update(set_6)

# %%
set_5
# Out:
# {'s', 't'}

# %%
set_5.intersection(set_6)
# Out:
# set()

# %%
set_5 | set_6
# Out:
# {'d', 'f', 'k', 'n', 's', 't', 'ı'}

# %%
set_5.union(set_6)
# Out:
# {'d', 'f', 'k', 'n', 's', 't', 'ı'}

# %%
set_5.update(set_6)

# %%
set_5
# Out:
# {'d', 'f', 'k', 'n', 's', 't', 'ı'}

# %%
set_7 = set("kadı")
set_7
# Out:
# {'a', 'd', 'k', 'ı'}

# %%
set_5 = set("fıstık")

# %%
set_5 | set_6 | set_7
# Out:
# {'a', 'd', 'f', 'k', 'n', 's', 't', 'ı'}

# %%
set_6 - set_5 - set_7
# Out:
# {'n'}

# %%
set_6.difference(set_5).difference(set_7)
# Out:
# {'n'}

# %% [markdown]
# ## clear()

# %%
set_5
# Out:
# {'f', 'k', 's', 't', 'ı'}

# %%
set_5.clear()

# %%
set_5
# Out:
# set()

# %% [markdown]
# remove()

# %%
set_6
# Out:
# {'d', 'f', 'k', 'n', 'ı'}

# %%
set_6.remove("d")

# %%
set_6
# Out:
# {'f', 'k', 'n', 'ı'}

# %%
set_6.remove("a")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 set_6.remove("a")
#
# KeyError: 'a'

# %% [markdown]
# ## discard()

# %%
set_8 = set("techpro")

# %%
set_8.discard("c")

# %%
set_8
# Out:
# {'e', 'h', 'o', 'p', 'r', 't'}

# %%
set_8.discard("a")

# %%
set_8
# Out:
# {'e', 'h', 'o', 'p', 'r', 't'}

# %% [markdown]
# ## pop()

# %%
set_7
# Out:
# {'a', 'd', 'k', 'ı'}

# %%
set_7.pop()
# Out:
# 'ı'

# %%
set_7.pop()
# Out:
# 'd'

# %%
set_7.pop()
# Out:
# 'k'

# %%
set_7.pop()
# Out:
# 'a'

# %%
set_7.pop() # rastgele eleman siler
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 set_7.pop() # rastgele eleman siler
#
# KeyError: 'pop from an empty set'

# %% [markdown]
# ## add()

# %%
set_7
# Out:
# set()

# %%
set_7.add("a")

# %%
set_7
# Out:
# {'a'}

# %%
set_7.add("d")

# %%
set_7
# Out:
# {'a', 'd'}

# %%
set_7.add("a" , "e")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 set_7.add("a" , "e")
#
# TypeError: set.add() takes exactly one argument (2 given)

# %%
set_7.add(["m" , "l"]) # kümeler içerisinde liste tipini tutamazlar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 set_7.add(["m" , "l"]) # kümeler içerisinde liste tipini tutamazlar
#
# TypeError: unhashable type: 'list'

# %%
set_7.add(("m","l")) # kümeler içerisinde tuple tipini tutabilirler

# %%
set_7
# Out:
# {('m', 'l'), 'a', 'a , e', 'd'}

# %%
{[1,2,3],5,4,True,"ömer"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 {[1,2,3],5,4,True,"ömer"}
#
# TypeError: unhashable type: 'list'

# %%
{5,4,True,"ömer"}
# Out:
# {4, 5, True, 'ömer'}

# %% [markdown]
# ## issubset()

# %%
 set_9 = set("selin")
 set_9
# Out:
# {'e', 'i', 'l', 'n', 's'}

# %%
set_10 = set("enes")
set_10
# Out:
# {'e', 'n', 's'}

# %%
set_10.issubset(set_9) # set_10 , set_9 un alt kümesi midir ?
# Out:
# True

# %%
set_9.issubset(set_10) # set_9 , set_10 un alt kümesi midir ?
# Out:
# False

# %%
set().issubset(set_9)
# Out:
# True
